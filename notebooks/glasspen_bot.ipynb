# %% [markdown]
# # Glass Pen Bot

# %% [markdown]
# ### 0. Проверка установленных библиотек

# %%
# bash
python -m venv venv  # Создаем виртуальное окружение
# source venv/bin/activate  # Активируем (Linux/Mac)
# venv\Scripts\activate     # Активируем (Windows)
# Out:
#   Cell In[15], line 2
#     python -m venv venv  # Создаем виртуальное окружение
#               ^
# SyntaxError: invalid syntax

# %%
pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting annotated-types==0.7.0 (from -r ../requirements.txt (line 1))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting attrs==25.3.0 (from -r ../requirements.txt (line 2))
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting beautifulsoup4==4.13.4 (from -r ../requirements.txt (line 3))
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting bs4==0.0.2 (from -r ../requirements.txt (line 4))
#   Using cached bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting cachetools==5.5.2 (from -r ../requirements.txt (line 5))
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting certifi==2025.4.26 (from -r ../requirements.txt (line 6))
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: cffi==1.17.1 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 7)) (1.17.1)
# Collecting charset-normalizer==3.4.2 (from -r ../requirements.txt (line 8))
#   Using cached charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Requirement already satisfied: colorama==0.4.6 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 9)) (0.4.6)
# Collecting cryptography==44.0.2 (from -r ../requirements.txt (line 10))
#   Using cached cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting DateTime==5.5 (from -r ../requirements.txt (line 11))
#   Using cached DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Collecting google-auth==2.39.0 (from -r ../requirements.txt (line 12))
#   Using cached google_auth-2.39.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-oauthlib==1.2.2 (from -r ../requirements.txt (line 13))
#   Using cached google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting gspread==6.2.0 (from -r ../requirements.txt (line 14))
#   Using cached gspread-6.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting h11==0.16.0 (from -r ../requirements.txt (line 15))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting httpx==0.23.3 (from -r ../requirements.txt (line 16))
#   Downloading httpx-0.23.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting idna==3.10 (from -r ../requirements.txt (line 17))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting JsonForm==0.0.2 (from -r ../requirements.txt (line 18))
#   Using cached jsonform-0.0.2-py3-none-any.whl
# Requirement already satisfied: jsonschema==4.23.0 in c:\programdata\anaconda3\lib\site-packages (from -r ../requirements.txt (line 19)) (4.23.0)
# Collecting jsonschema-specifications==2025.4.1 (from -r ../requirements.txt (line 20))
#   Using cached jsonschema_specifications-2025.4.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting JsonSir==0.0.2 (from -r ../requirements.txt (line 21))
#   Using cached jsonsir-0.0.2-py3-none-any.whl
# Collecting logging==0.4.9.6 (from -r ../requirements.txt (line 22))
#   Using cached logging-0.4.9.6-py3-none-any.whl
# ERROR: Could not find a version that satisfies the requirement numpy==2.2.5 (from versions: none)
# ERROR: No matching distribution found for numpy==2.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# В Jupyter Notebook или Python
import telegram
import httpx

print(f"python-telegram-bot версия: {telegram.__version__}")
print(f"httpx версия: {httpx.__version__}")
# Out:
# python-telegram-bot версия: 21.11.1
# httpx версия: 0.26.0

# %%
# !pip install httpx==0.26.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting httpx==0.26.0
#   Using cached httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx==0.26.0) (4.2.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx==0.26.0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\roaming\python\python312\site-packages (from httpx==0.26.0) (1.0.9)
#   WARNING: The script httpx.exe is installed in 'C:\Users\User\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googletrans 4.0.0rc1 requires httpx==0.13.3, but you have httpx 0.26.0 which is incompatible.
# Requirement already satisfied: idna in c:\users\user\appdata\roaming\python\python312\site-packages (from httpx==0.26.0) (2.10)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx==0.26.0) (1.3.0)
# Requirement already satisfied: h11>=0.16 in c:\users\user\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx==0.26.0) (0.16.0)
# Using cached httpx-0.26.0-py3-none-any.whl (75 kB)
# Installing collected packages: httpx
# Successfully installed httpx-0.26.0

# %%
# Удалите текущие версии
# !pip uninstall python-telegram-bot httpx -y
# Out:
# Found existing installation: httpx 0.23.3
# Uninstalling httpx-0.23.3:
#   Successfully uninstalled httpx-0.23.3
# WARNING: Skipping python-telegram-bot as it is not installed.

# %%
# Удалите текущие версии
# !pip uninstall httpx -y
# Out:
# Found existing installation: httpx 0.26.0
# Uninstalling httpx-0.26.0:
#   Successfully uninstalled httpx-0.26.0

# %%
# Установите совместимые версии
# !pip install python-telegram-bot==20.3 httpx==0.23.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-telegram-bot==20.3
#   Downloading python_telegram_bot-20.3-py3-none-any.whl.metadata (15 kB)
# Collecting httpx==0.23.3
#   Using cached httpx-0.23.3-py3-none-any.whl.metadata (7.1 kB)
# INFO: pip is looking at multiple versions of python-telegram-bot to determine which version is compatible with other requirements. This could take a while.
#
# The conflict is caused by:
#     The user requested httpx==0.23.3
#     python-telegram-bot 20.3 depends on httpx~=0.24.0
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip to attempt to solve the dependency conflict
# ERROR: Cannot install httpx==0.23.3 and python-telegram-bot==20.3 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts

# %% [markdown]
# ## 1. Загрузка библиотек - START_TEST_1 !!! - START_1 !!!
# Все библиотеки для работы проекта в одном месте

# %%
import logging
from telegram import Update, ReplyKeyboardMarkup, InlineKeyboardMarkup, InlineKeyboardButton
from telegram.ext import Application, CommandHandler, MessageHandler, filters, ContextTypes, CallbackQueryHandler
from telegram.ext import CallbackContext

# %% [markdown]
# ## 2. Тестирование отдельных блоков кода

# %%
# Настройка логирования
logging.basicConfig(
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    level=logging.INFO
)
logger = logging.getLogger(__name__)

# %%
# Токен бота (получите у @BotFather)
BOT_TOKEN = "7918395635:AAEoAYwkrtorZqvwkksTB73QutUa0whCsBo"

# ID чата для пересылки вопросов (можно узнать через @userinfobot)
ADMIN_CHAT_ID = "7156086085"

# %%
# Обработчик команды /start
async def start_command(update: Update, context: CallbackContext) -> None:
    # Создаем кастомную клавиатуру
    keyboard = [
        ["📚 Ссылка на канал", "📖 Оглавление"],
        ["❓ Задать вопрос авторам"]
    ]
    reply_markup = ReplyKeyboardMarkup(keyboard, resize_keyboard=True)
    
    welcome_text = """
Приветствую в литературном уголке! 📚

Я помогу вам:
• Найти ссылку на наш канал
• Показать оглавление произведений  
• Направить ваш вопрос авторам

Выберите действие ниже 👇
"""
    await update.message.reply_text(welcome_text, reply_markup=reply_markup)

# %%
# Обработчик команды /link
async def link_command(update: Update, context: CallbackContext) -> None:
    link_text = """
📚 **Ссылка на наш канал:** 
[Литературный уголок](https://t.me/glass_pen)

**Как поделиться конкретным постом?**
1. Откройте нужный пост в канале
2. Нажмите на кнопку "↗️" (Поделиться)  
3. Выберите "Скопировать ссылку"
"""
    await update.message.reply_text(link_text, parse_mode='Markdown')

# %%
# Обработчик для инлайн-кнопок оглавления
async def handle_inline_buttons(update: Update, context: CallbackContext) -> None:
    query = update.callback_query
    await query.answer()
    
    # Обрабатываем нажатие на разные кнопки
    data = query.data
    
    if data == "love_poems":
        response = "**Стихи о любви:**\n\n• 'Первая встреча' - /post_1\n• 'Вечерний звон' - /post_2\n• 'Без ответа' - /post_3"
    elif data == "prose":
        response = "**Проза:**\n\n• 'Утренний туман' - /post_4\n• 'Старый дом' - /post_5"
    elif data == "analysis":
        response = "**Анализ произведений:**\n\n• 'Символика в поэзии' - /post_6\n• 'Особенности стиля' - /post_7"
    
    await query.edit_message_text(response, parse_mode='Markdown')

# %%
# Обработчик команды /contents
async def contents_command(update: Update, context: CallbackContext) -> None:
    # Создаем инлайн-клавиатуру
    keyboard = [
        [InlineKeyboardButton("💖 Стихи о любви", callback_data="love_poems")],
        [InlineKeyboardButton("📖 Проза", callback_data="prose")],
        [InlineKeyboardButton("🔍 Анализ произведений", callback_data="analysis")]
    ]
    reply_markup = InlineKeyboardMarkup(keyboard)
    
    await update.message.reply_text(
        "📚 **Выберите раздел:**",
        reply_markup=reply_markup,
        parse_mode='Markdown'
    )

# %%
# Обработчик для вопросов авторам
async def question_command(update: Update, context: CallbackContext) -> None:
    instruction = """
✍️ **Задать вопрос авторам**

Опишите, пожалуйста, ваш вопрос или пожелание. Мы прочитаем его и постараемся ответить в ближайшее время.

*Просто напишите ваш вопрос в чат...*
"""
    # Сохраняем состояние, что ждем вопрос
    context.user_data['awaiting_question'] = True
    await update.message.reply_text(instruction, parse_mode='Markdown')

# %%
# Обработчик текстовых сообщений (для вопросов)
async def handle_message(update: Update, context: CallbackContext) -> None:
    user_data = context.user_data
    
    # Проверяем, ждем ли мы вопрос от пользователя
    if user_data.get('awaiting_question'):
        user = update.message.from_user
        question_text = update.message.text
        
        # Формируем сообщение для админа
        admin_message = f"""
❓ **Новый вопрос от** @{user.username} ({user.first_name}):

{question_text}
"""
        # Пересылаем вопрос админу
        await context.bot.send_message(
            chat_id=ADMIN_CHAT_ID,
            text=admin_message,
            parse_mode='Markdown'
        )
        
        # Подтверждаем пользователю
        await update.message.reply_text(
            "✅ Спасибо! Ваш вопрос отправлен авторам. Мы ответим вам в ближайшее время.",
            parse_mode='Markdown'
        )
        
        # Сбрасываем состояние
        user_data['awaiting_question'] = False
    else:
        # Если это обычное сообщение, не связанное с вопросом
        await update.message.reply_text(
            "Используйте кнопки меню для навигации 🗺️",
            parse_mode='Markdown'
        )

# %%
# Обработчик кнопок главного меню
async def handle_main_menu_buttons(update: Update, context: CallbackContext) -> None:
    text = update.message.text
    
    if text == "📚 Ссылка на канал":
        await link_command(update, context)
    elif text == "📖 Оглавление":
        await contents_command(update, context)
    elif text == "❓ Задать вопрос авторам":
        await question_command(update, context)

# %%
# Основная функция
def main():
    # Создаем приложение
    application = Application.builder().token(BOT_TOKEN).build()
    
    # Добавляем обработчики команд
    application.add_handler(CommandHandler("start", start_command))
    application.add_handler(CommandHandler("link", link_command))
    application.add_handler(CommandHandler("contents", contents_command))
    application.add_handler(CommandHandler("question", question_command))
    
    # Обработчик инлайн-кнопок (для оглавления)
    application.add_handler(CallbackQueryHandler(handle_inline_buttons))
    
    # Обработчик текстовых сообщений (для вопросов)
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, handle_message))
    
    # Обработчик кнопок главного меню (используем Regex)
    application.add_handler(MessageHandler(
        filters.Regex(r'^(📚 Ссылка на канал|📖 Оглавление|❓ Задать вопрос авторам)$'),
        handle_main_menu_buttons
    ))
    
    # Запускаем бота
    print("Бот запущен...")
    application.run_polling()

# %%
if __name__ == '__main__':
    main()
# Out:
# Бот запущен...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\ext\_application.py:1087, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1086 try:
# -> 1087     loop.run_until_complete(self._bootstrap_initialize(max_retries=bootstrap_retries))
#    1088     if self.post_init:
#
# File C:\ProgramData\anaconda3\Lib\asyncio\base_events.py:663, in BaseEventLoop.run_until_complete(self, future)
#     662 self._check_closed()
# --> 663 self._check_running()
#     665 new_task = not futures.isfuture(future)
#
# File C:\ProgramData\anaconda3\Lib\asyncio\base_events.py:622, in BaseEventLoop._check_running(self)
#     621 if self.is_running():
# --> 622     raise RuntimeError('This event loop is already running')
#     623 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\ext\_application.py:1112, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1111         loop.run_until_complete(self.post_stop(self))
# -> 1112 loop.run_until_complete(self.shutdown())
#    1113 if self.post_shutdown:
#
# File C:\ProgramData\anaconda3\Lib\asyncio\base_events.py:663, in BaseEventLoop.run_until_complete(self, future)
#     662 self._check_closed()
# --> 663 self._check_running()
#     665 new_task = not futures.isfuture(future)
#
# File C:\ProgramData\anaconda3\Lib\asyncio\base_events.py:622, in BaseEventLoop._check_running(self)
#     621 if self.is_running():
# --> 622     raise RuntimeError('This event loop is already running')
#     623 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 2
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# Cell In[10], line 26, in main()
#      24 # Запускаем бота
#      25 print("Бот запущен...")
# ---> 26 application.run_polling()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\ext\_application.py:873, in Application.run_polling(self, poll_interval, timeout, bootstrap_retries, read_timeout, write_timeout, connect_timeout, pool_timeout, allowed_updates, drop_pending_updates, close_loop, stop_signals)
#     870 def error_callback(exc: TelegramError) -> None:
#     871     self.create_task(self.process_error(error=exc, update=None))
# --> 873 return self.__run(
#     874     updater_coroutine=self.updater.start_polling(
#     875         poll_interval=poll_interval,
#     876         timeout=timeout,
#     877         bootstrap_retries=bootstrap_retries,
#     878         read_timeout=read_timeout,
#     879         write_timeout=write_timeout,
#     880         connect_timeout=connect_timeout,
#     881         pool_timeout=pool_timeout,
#     882         allowed_updates=allowed_updates,
#     883         drop_pending_updates=drop_pending_updates,
#     884         error_callback=error_callback,  # if there is an error in fetching updates
#     885     ),
#     886     stop_signals=stop_signals,
#     887     bootstrap_retries=bootstrap_retries,
#     888     close_loop=close_loop,
#     889 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\ext\_application.py:1117, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1115 finally:
#    1116     if close_loop:
# -> 1117         loop.close()
#
# File C:\ProgramData\anaconda3\Lib\asyncio\proactor_events.py:687, in BaseProactorEventLoop.close(self)
#     685 def close(self):
#     686     if self.is_running():
# --> 687         raise RuntimeError("Cannot close a running event loop")
#     688     if self.is_closed():
#     689         return
#
# RuntimeError: Cannot close a running event loop

# %% [markdown]
# ## Raw code - Сырой код

# %%
import logging
from telegram import Update, ReplyKeyboardMarkup, InlineKeyboardMarkup, InlineKeyboardButton
from telegram.ext import Application, CommandHandler, MessageHandler, filters, ContextTypes, CallbackQueryHandler
from telegram.ext import CallbackContext

# Настройка логирования
logging.basicConfig(
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    level=logging.INFO
)
logger = logging.getLogger(__name__)

# Токен бота (получите у @BotFather)
BOT_TOKEN = "7918395635:AAEoAYwkrtorZqvwkksTB73QutUa0whCsBo"

# ID чата для пересылки вопросов (можно узнать через @userinfobot)
ADMIN_CHAT_ID = "7156086085"

# Обработчик команды /start
async def start_command(update: Update, context: CallbackContext) -> None:
    # Создаем кастомную клавиатуру
    keyboard = [
        ["📚 Ссылка на канал", "📖 Оглавление"],
        ["❓ Задать вопрос авторам"]
    ]
    reply_markup = ReplyKeyboardMarkup(keyboard, resize_keyboard=True)
    
    welcome_text = """
Приветствую в литературном уголке! 📚

Я помогу вам:
• Найти ссылку на наш канал
• Показать оглавление произведений  
• Направить ваш вопрос авторам

Выберите действие ниже 👇
"""
    await update.message.reply_text(welcome_text, reply_markup=reply_markup)

# Обработчик команды /link
async def link_command(update: Update, context: CallbackContext) -> None:
    link_text = """
📚 **Ссылка на наш канал:** 
[Литературный уголок](https://t.me/glass_pen)

**Как поделиться конкретным постом?**
1. Откройте нужный пост в канале
2. Нажмите на кнопку "↗️" (Поделиться)  
3. Выберите "Скопировать ссылку"
"""
    await update.message.reply_text(link_text, parse_mode='Markdown')

# Обработчик для инлайн-кнопок оглавления
async def handle_inline_buttons(update: Update, context: CallbackContext) -> None:
    query = update.callback_query
    await query.answer()
    
    # Обрабатываем нажатие на разные кнопки
    data = query.data
    
    if data == "love_poems":
        response = "**Стихи о любви:**\n\n• 'Первая встреча' - /post_1\n• 'Вечерний звон' - /post_2\n• 'Без ответа' - /post_3"
    elif data == "prose":
        response = "**Проза:**\n\n• 'Утренний туман' - /post_4\n• 'Старый дом' - /post_5"
    elif data == "analysis":
        response = "**Анализ произведений:**\n\n• 'Символика в поэзии' - /post_6\n• 'Особенности стиля' - /post_7"
    
    await query.edit_message_text(response, parse_mode='Markdown')

# Обработчик команды /contents
async def contents_command(update: Update, context: CallbackContext) -> None:
    # Создаем инлайн-клавиатуру
    keyboard = [
        [InlineKeyboardButton("💖 Стихи о любви", callback_data="love_poems")],
        [InlineKeyboardButton("📖 Проза", callback_data="prose")],
        [InlineKeyboardButton("🔍 Анализ произведений", callback_data="analysis")]
    ]
    reply_markup = InlineKeyboardMarkup(keyboard)
    
    await update.message.reply_text(
        "📚 **Выберите раздел:**",
        reply_markup=reply_markup,
        parse_mode='Markdown'
    )

# Обработчик для вопросов авторам
async def question_command(update: Update, context: CallbackContext) -> None:
    instruction = """
✍️ **Задать вопрос авторам**

Опишите, пожалуйста, ваш вопрос или пожелание. Мы прочитаем его и постараемся ответить в ближайшее время.

*Просто напишите ваш вопрос в чат...*
"""
    # Сохраняем состояние, что ждем вопрос
    context.user_data['awaiting_question'] = True
    await update.message.reply_text(instruction, parse_mode='Markdown')

# Обработчик текстовых сообщений (для вопросов)
async def handle_message(update: Update, context: CallbackContext) -> None:
    user_data = context.user_data
    
    # Проверяем, ждем ли мы вопрос от пользователя
    if user_data.get('awaiting_question'):
        user = update.message.from_user
        question_text = update.message.text
        
        # Формируем сообщение для админа
        admin_message = f"""
❓ **Новый вопрос от** @{user.username} ({user.first_name}):

{question_text}
"""
        # Пересылаем вопрос админу
        await context.bot.send_message(
            chat_id=ADMIN_CHAT_ID,
            text=admin_message,
            parse_mode='Markdown'
        )
        
        # Подтверждаем пользователю
        await update.message.reply_text(
            "✅ Спасибо! Ваш вопрос отправлен авторам. Мы ответим вам в ближайшее время.",
            parse_mode='Markdown'
        )
        
        # Сбрасываем состояние
        user_data['awaiting_question'] = False
    else:
        # Если это обычное сообщение, не связанное с вопросом
        await update.message.reply_text(
            "Используйте кнопки меню для навигации 🗺️",
            parse_mode='Markdown'
        )

# Обработчик кнопок главного меню
async def handle_main_menu_buttons(update: Update, context: CallbackContext) -> None:
    text = update.message.text
    
    if text == "📚 Ссылка на канал":
        await link_command(update, context)
    elif text == "📖 Оглавление":
        await contents_command(update, context)
    elif text == "❓ Задать вопрос авторам":
        await question_command(update, context)

# Основная функция
def main():
    # Создаем приложение
    application = Application.builder().token(BOT_TOKEN).build()
    
    # Добавляем обработчики команд
    application.add_handler(CommandHandler("start", start_command))
    application.add_handler(CommandHandler("link", link_command))
    application.add_handler(CommandHandler("contents", contents_command))
    application.add_handler(CommandHandler("question", question_command))
    
    # Обработчик инлайн-кнопок (для оглавления)
    application.add_handler(CallbackQueryHandler(handle_inline_buttons))
    
    # Обработчик текстовых сообщений (для вопросов)
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, handle_message))
    
    # Обработчик кнопок главного меню (используем Regex)
    application.add_handler(MessageHandler(
        filters.Regex(r'^(📚 Ссылка на канал|📖 Оглавление|❓ Задать вопрос авторам)$'),
        handle_main_menu_buttons
    ))
    
    # Запускаем бота
    print("Бот запущен...")
    application.run_polling()

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 175
#     172     application.run_polling()
#     174 if __name__ == '__main__':
# --> 175     main()
#
# Cell In[35], line 150, in main()
#     148 def main():
#     149     # Создаем приложение
# --> 150     application = Application.builder().token(BOT_TOKEN).build()
#     152     # Добавляем обработчики команд
#     153     application.add_handler(CommandHandler("start", start_command))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\ext\_applicationbuilder.py:307, in ApplicationBuilder.build(self)
#     305 if isinstance(self._updater, DefaultValue) or self._updater is None:
#     306     if isinstance(self._bot, DefaultValue):  # and didn't set a bot
# --> 307         bot: Bot = self._build_ext_bot()  # build a bot
#     308     else:
#     309         bot = self._bot
#
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\ext\_applicationbuilder.py:277, in ApplicationBuilder._build_ext_bot(self)
#     266 if isinstance(self._token, DefaultValue):
#     267     raise RuntimeError("No bot token was set.")
#     269 return ExtBot(
#     270     token=self._token,
#     271     base_url=DefaultValue.get_value(self._base_url),
#     272     base_file_url=DefaultValue.get_value(self._base_file_url),
#     273     private_key=DefaultValue.get_value(self._private_key),
#     274     private_key_password=DefaultValue.get_value(self._private_key_password),
#     275     defaults=DefaultValue.get_value(self._defaults),
#     276     arbitrary_callback_data=DefaultValue.get_value(self._arbitrary_callback_data),
# --> 277     request=self._build_request(get_updates=False),
#     278     get_updates_request=self._build_request(get_updates=True),
#     279     rate_limiter=DefaultValue.get_value(self._rate_limiter),
#     280     local_mode=DefaultValue.get_value(self._local_mode),
#     281 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\ext\_applicationbuilder.py:257, in ApplicationBuilder._build_request(self, get_updates)
#     251 effective_timeouts = {
#     252     key: value for key, value in timeouts.items() if not isinstance(value, DefaultValue)
#     253 }
#     255 http_version = DefaultValue.get_value(getattr(self, f"{prefix}http_version")) or "1.1"
# --> 257 return HTTPXRequest(
#     258     connection_pool_size=connection_pool_size,
#     259     proxy=proxy,
#     260     http_version=http_version,  # type: ignore[arg-type]
#     261     socket_options=socket_options,
#     262     **effective_timeouts,
#     263 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\telegram\request\_httpxrequest.py:173, in HTTPXRequest.__init__(self, connection_pool_size, proxy_url, read_timeout, write_timeout, connect_timeout, pool_timeout, http_version, socket_options, proxy, media_write_timeout, httpx_kwargs)
#     171 self._http_version = http_version
#     172 self._media_write_timeout = media_write_timeout
# --> 173 timeout = httpx.Timeout(
#     174     connect=connect_timeout,
#     175     read=read_timeout,
#     176     write=write_timeout,
#     177     pool=pool_timeout,
#     178 )
#     179 limits = httpx.Limits(
#     180     max_connections=connection_pool_size,
#     181     max_keepalive_connections=connection_pool_size,
#     182 )
#     184 if http_version not in ("1.1", "2", "2.0"):
#
# TypeError: Timeout.__init__() got an unexpected keyword argument 'connect'
